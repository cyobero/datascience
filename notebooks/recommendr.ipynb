# %% [markdown]
# # Recommdender System
#
# In this tutorial we build a recommendation system using deep learning.

# %% [markdown]
# # Set Up

# %%
# @title Imports (run this cell)
from __future__ import print_function

import numpy as np
import pandas as pd
import collections
from mpl_toolkits.mplot3d import Axes3D
from IPython import display
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import Normalizer, LabelEncoder
from sklearn.linear_model import LinearRegression
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
import tensorflow as tf
tf.logging.set_verbosity(tf.logging.ERROR)

# %% [markdown]
# # Load and Preprocess Data

# %% [markdown]
# ## Load MovieLens Dataset
# The dataset we use for this tutorial is the [MovieLens](https://movielens.org/) dataset.

# %%
from urllib.request import urlretrieve
import zipfile

urlretrieve('http://files.grouplens.org/datasets/movielens/ml-100k.zip',
             'movielens.zip')
zip_ = zipfile.ZipFile('movielens.zip', 'r')
zip_.extractall()

# %%
# Load each dataset

# Users df
users_cols = ['user_id', 'age', 'sex', 'occupation', 'zip_code']
users = pd.read_csv(
    'ml-100k/u.user', sep='|', names=users_cols, encoding='latin-1')

# Ratings df
ratings_cols = ['user_id', 'movie_id', 'rating', 'unix_timestamp']
ratings = pd.read_csv(
    'ml-100k/u.data', sep='\t', names=ratings_cols,encoding='latin-1')

# Genres df
genre_cols = [
    'genre_unknown', 'Action', 'Adventure', 'Animation', 'Children', 'Comedy',
    'Crime', 'Documentary', 'Drama', 'Fantasy', 'Film-Noir', 'Horror', 
    'Musical', 'Mystery', 'Romance', 'Sci-Fi', 'Thriller', 'War', 'Western']

# Movies (with `genre_cols`) df
movies_cols = [
    'movie_id', 'title', 'release_date',
    'video_release_data', 'imdb_url'] + genre_cols
movies = pd.read_csv(
    'ml-100k/u.item', sep='|', names=movies_cols, encoding='latin-1')

# Since IDs start at 1, we shift so they start at 0.
users["user_id"] = users["user_id"].apply(lambda x: str(x-1))
movies["movie_id"] = movies["movie_id"].apply(lambda x: str(x-1))
movies["year"] = movies['release_date'].apply(lambda x: str(x).split('-')[-1])
ratings["movie_id"] = ratings["movie_id"].apply(lambda x: str(x-1))
ratings["user_id"] = ratings["user_id"].apply(lambda x: str(x-1))
ratings["rating"] = ratings["rating"].apply(lambda x: float(x))

# %% [markdown]
# Since some movies can belong to more than one genre, we create different `genre` column as follows:
# - `all_genres`: all active genres for a movie
# - `genre`: randomply sampled from the active genres

# %%
def mark_genres(movies, genres):

    def get_random_genre(gs):
        active = [genre for genre, g in zip(genres, gs) if g==1]
        if len(active) == 0:
            return 'Other'
        return np.random.choice(active)
    
    def get_all_genres(gs):
        active = [genre for genre, g in zip(genres, gs) if g==1]
        if len(active) == 0:
            return 'Other'
        return '-'.join(active)

    def get_all_genres(gs):
        active = [genre for genre, g in zip(genres, gs) if g==1]
        if len(active) == 0:
            return 'Other'
        return '-'.join(active)

    movies['genre'] = [
        get_random_genre(gs) for gs in zip(*[movies[genre] for genre in genres])]
    movies['all_genres'] = [
        get_all_genres(gs) for gs in zip(*[movies[genre] for genre in genres])]


mark_genres(movies, genre_cols)

# %%
le = LabelEncoder()

# %%
movie_lens = users.merge(ratings, on=['user_id'])
movie_lens = movie_lens.merge(movies, on=['movie_id'])
movie_lens = movie_lens[['age', 'sex', 'occupation', 'zip_code',
                         'rating', 'year', 'all_genres']]

movie_lens.head()
# Out:
#    age sex  occupation zip_code  rating  year all_genres
# 0   24   M  technician    85711     4.0  1994      Drama
# 1   47   M    educator    29206     4.0  1994      Drama
# 2   35   F       other    37212     4.0  1994      Drama
# 3   27   M  programmer    52246     5.0  1994      Drama
# 4   49   M    educator    08403     4.0  1994      Drama

# %%
def normalize(X):
    mean = np.mean(X)
    std = np.std(X)
    normed = [(x-mean)/std for x in X]
    return normed

CATEGORICAL_FEATURES = ['sex', 'occupation', 'zip_code', 'year', 'all_genres']
NUMERICAL_FEATURES = ['age']
movie_lens[CATEGORICAL_FEATURES] = movie_lens[CATEGORICAL_FEATURES].apply(le.fit_transform, 0)
movie_lens[NUMERICAL_FEATURES] = movie_lens[NUMERICAL_FEATURES].apply(normalize, 0)

# %%
dataset = np.array(movie_lens)
dataset = tf.data.Dataset.from_tensors(dataset)

# %%
X = np.array(movie_lens[['age', 'sex', 'occupation', 'zip_code',
                         'year', 'all_genres']])
y = np.array(movie_lens['rating'])

X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
# feature columns
age = tf.feature_column.numeric_column('age')
sex = tf.feature_column.numeric_column('sex')
occupation = tf.feature_column.numeric_column('occupation')
zip_code = tf.feature_column.numeric_column('zip_code')
year = tf.feature_column.numeric_column('year')
genres = tf.feature_column.numeric_column('genres')

optimizer = tf.keras.optimizers.RMSprop(0.001)
estimator = tf.estimator.DNNClassifier(64, feature_columns=[age,
                                                            sex, 
                                                            occupation,
                                                            zip_code, 
                                                            year, 
                                                            genres],
                                       optimizer=optimizer)

# %%
train_dataset = tf.data.Dataset.from_tensor_slices(X_train)
train_labels = tf.data.Dataset.from_tensor_slices(y_train)

# %%
def build_model():
    model = tf.keras.Sequential([
        tf.keras.layers.Dense(64, activation='relu', input_shape=[6]),
        tf.keras.layers.Dense(64, activation='relu'),
        tf.keras.layers.Dropout(rate=0.3), 
        tf.keras.layers.Dense(1)
    ])

    optimizer = tf.keras.optimizers.RMSprop(learning_rate=1e-6)
    model.compile(loss='mse', optimizer=optimizer, metrics=['mae', 'mse'])
    return model

# %%
model = build_model()

# %%
model.fit(X_train, y_train, epochs=100)
# Out:
# Train on 75000 samples
# Epoch 1/100
# 75000/75000 [==============================] - 9s 121us/sample - loss: 3287.7337 - mean_absolute_error: 45.3825 - mean_squared_error: 3287.7310
# Epoch 2/100
# 75000/75000 [==============================] - 9s 121us/sample - loss: 1398.8813 - mean_absolute_error: 27.9307 - mean_squared_error: 1398.8813
# Epoch 3/100
# 75000/75000 [==============================] - 9s 126us/sample - loss: 833.2355 - mean_absolute_error: 21.4886 - mean_squared_error: 833.2348
# Epoch 4/100
# 75000/75000 [==============================] - 9s 126us/sample - loss: 694.9942 - mean_absolute_error: 19.6741 - mean_squared_error: 694.9946
# Epoch 5/100
# 75000/75000 [==============================] - 9s 119us/sample - loss: 593.0430 - mean_absolute_error: 18.1625 - mean_squared_error: 593.0418
# Epoch 6/100
# 75000/75000 [==============================] - 9s 121us/sample - loss: 505.5499 - mean_absolute_error: 16.7924 - mean_squared_error: 505.5498
# Epoch 7/100
# 75000/75000 [==============================] - 9s 123us/sample - loss: 427.4018 - mean_absolute_error: 15.4503 - mean_squared_error: 427.4017
# Epoch 8/100
# 75000/75000 [==============================] - 9s 123us/sample - loss: 350.5324 - mean_absolute_error: 14.0481 - mean_squared_error: 350.5319
# Epoch 9/100
# 75000/75000 [==============================] - 9s 126us/sample - loss: 289.8152 - mean_absolute_error: 12.7681 - mean_squared_error: 289.8152
# Epoch 10/100
# 75000/75000 [==============================] - 9s 127us/sample - loss: 235.2608 - mean_absolute_error: 11.5622 - mean_squared_error: 235.2606
# Epoch 11/100
# 75000/75000 [==============================] - 9s 125us/sample - loss: 189.4005 - mean_absolute_error: 10.4075 - mean_squared_error: 189.4003
# Epoch 12/100
# 75000/75000 [==============================] - 9s 123us/sample - loss: 150.1614 - mean_absolute_error: 9.3317 - mean_squared_error: 150.1614
# Epoch 13/100
# 75000/75000 [==============================] - 9s 119us/sample - loss: 115.3811 - mean_absolute_error: 8.2065 - mean_squared_error: 115.3810
# Epoch 14/100
# 75000/75000 [==============================] - 9s 118us/sample - loss: 87.9389 - mean_absolute_error: 7.2018 - mean_squared_error: 87.9388
# Epoch 15/100
# 75000/75000 [==============================] - 9s 119us/sample - loss: 66.5228 - mean_absolute_error: 6.2848 - mean_squared_error: 66.5228
# Epoch 16/100
# 75000/75000 [==============================] - 10s 127us/sample - loss: 48.6521 - mean_absolute_error: 5.4203 - mean_squared_error: 48.6521
# Epoch 17/100
# 75000/75000 [==============================] - 9s 118us/sample - loss: 35.3977 - mean_absolute_error: 4.6456 - mean_squared_error: 35.3977
# Epoch 18/100
# 75000/75000 [==============================] - 9s 121us/sample - loss: 26.0673 - mean_absolute_error: 3.9928 - mean_squared_error: 26.0673
# Epoch 19/100
# 75000/75000 [==============================] - 9s 126us/sample - loss: 19.4634 - mean_absolute_error: 3.4577 - mean_squared_error: 19.4634
# Epoch 20/100
# 75000/75000 [==============================] - 9s 123us/sample - loss: 14.8754 - mean_absolute_error: 3.0185 - mean_squared_error: 14.8754
# Epoch 21/100
# 75000/75000 [==============================] - 9s 120us/sample - loss: 11.7696 - mean_absolute_error: 2.6811 - mean_squared_error: 11.7696
# Epoch 22/100
# 75000/75000 [==============================] - 9s 120us/sample - loss: 9.3273 - mean_absolute_error: 2.3786 - mean_squared_error: 9.3273
# Epoch 23/100
# 75000/75000 [==============================] - 9s 123us/sample - loss: 7.6481 - mean_absolute_error: 2.1550 - mean_squared_error: 7.6481
# Epoch 24/100
# 75000/75000 [==============================] - 9s 123us/sample - loss: 6.2769 - mean_absolute_error: 1.9430 - mean_squared_error: 6.2769
# Epoch 25/100
# 75000/75000 [==============================] - 9s 127us/sample - loss: 5.2226 - mean_absolute_error: 1.7717 - mean_squared_error: 5.2226
# Epoch 26/100
# 75000/75000 [==============================] - 9s 123us/sample - loss: 4.5393 - mean_absolute_error: 1.6548 - mean_squared_error: 4.5393
# Epoch 27/100
# 75000/75000 [==============================] - 9s 121us/sample - loss: 4.0518 - mean_absolute_error: 1.5702 - mean_squared_error: 4.0518
# Epoch 28/100
# 75000/75000 [==============================] - 9s 122us/sample - loss: 3.7268 - mean_absolute_error: 1.5097 - mean_squared_error: 3.7268
# Epoch 29/100
# 75000/75000 [==============================] - 9s 115us/sample - loss: 3.4387 - mean_absolute_error: 1.4570 - mean_squared_error: 3.4387
# Epoch 30/100
# 75000/75000 [==============================] - 9s 119us/sample - loss: 3.2384 - mean_absolute_error: 1.4209 - mean_squared_error: 3.2384
# Epoch 31/100
# 75000/75000 [==============================] - 9s 124us/sample - loss: 3.0698 - mean_absolute_error: 1.3849 - mean_squared_error: 3.0698
# Epoch 32/100
# 75000/75000 [==============================] - 9s 118us/sample - loss: 2.9377 - mean_absolute_error: 1.3621 - mean_squared_error: 2.9377
# Epoch 33/100
# 75000/75000 [==============================] - 9s 121us/sample - loss: 2.8235 - mean_absolute_error: 1.3365 - mean_squared_error: 2.8235
# Epoch 34/100
# 75000/75000 [==============================] - 9s 122us/sample - loss: 2.7561 - mean_absolute_error: 1.3255 - mean_squared_error: 2.7561
# Epoch 35/100
# 75000/75000 [==============================] - 9s 117us/sample - loss: 2.6617 - mean_absolute_error: 1.3052 - mean_squared_error: 2.6617
# Epoch 36/100
# 75000/75000 [==============================] - 9s 121us/sample - loss: 2.6016 - mean_absolute_error: 1.2899 - mean_squared_error: 2.6016
# Epoch 37/100
# 75000/75000 [==============================] - 9s 115us/sample - loss: 2.5660 - mean_absolute_error: 1.2861 - mean_squared_error: 2.5660
# Epoch 38/100
# 75000/75000 [==============================] - 9s 123us/sample - loss: 2.4995 - mean_absolute_error: 1.2708 - mean_squared_error: 2.4995
# Epoch 39/100
# 75000/75000 [==============================] - 9s 123us/sample - loss: 2.4744 - mean_absolute_error: 1.2649 - mean_squared_error: 2.4744
# Epoch 40/100
# 75000/75000 [==============================] - 10s 127us/sample - loss: 2.4177 - mean_absolute_error: 1.2516 - mean_squared_error: 2.4177
# Epoch 41/100
# 75000/75000 [==============================] - 9s 125us/sample - loss: 2.4007 - mean_absolute_error: 1.2483 - mean_squared_error: 2.4007
# Epoch 42/100
# 75000/75000 [==============================] - 9s 125us/sample - loss: 2.3785 - mean_absolute_error: 1.2424 - mean_squared_error: 2.3785
# Epoch 43/100
# 75000/75000 [==============================] - 9s 123us/sample - loss: 2.3498 - mean_absolute_error: 1.2367 - mean_squared_error: 2.3498
# Epoch 44/100
# 75000/75000 [==============================] - 9s 125us/sample - loss: 2.3348 - mean_absolute_error: 1.2321 - mean_squared_error: 2.3348
# Epoch 45/100
# 75000/75000 [==============================] - 9s 121us/sample - loss: 2.2986 - mean_absolute_error: 1.2227 - mean_squared_error: 2.2986
# Epoch 46/100
# 75000/75000 [==============================] - 9s 118us/sample - loss: 2.3024 - mean_absolute_error: 1.2243 - mean_squared_error: 2.3024
# Epoch 47/100
# 75000/75000 [==============================] - 9s 120us/sample - loss: 2.2866 - mean_absolute_error: 1.2212 - mean_squared_error: 2.2866
# Epoch 48/100
# 75000/75000 [==============================] - 9s 118us/sample - loss: 2.2425 - mean_absolute_error: 1.2086 - mean_squared_error: 2.2425
# Epoch 49/100
# 75000/75000 [==============================] - 9s 124us/sample - loss: 2.2493 - mean_absolute_error: 1.2132 - mean_squared_error: 2.2493
# Epoch 50/100
# 75000/75000 [==============================] - 9s 122us/sample - loss: 2.2322 - mean_absolute_error: 1.2074 - mean_squared_error: 2.2322
# Epoch 51/100
# 75000/75000 [==============================] - 9s 121us/sample - loss: 2.2297 - mean_absolute_error: 1.2065 - mean_squared_error: 2.2297
# Epoch 52/100
# 75000/75000 [==============================] - 9s 117us/sample - loss: 2.2235 - mean_absolute_error: 1.2060 - mean_squared_error: 2.2235
# Epoch 53/100
# 75000/75000 [==============================] - 9s 117us/sample - loss: 2.2140 - mean_absolute_error: 1.2025 - mean_squared_error: 2.2140
# Epoch 54/100
# 75000/75000 [==============================] - 9s 118us/sample - loss: 2.1863 - mean_absolute_error: 1.1937 - mean_squared_error: 2.1863
# Epoch 55/100
# 75000/75000 [==============================] - 9s 126us/sample - loss: 2.1995 - mean_absolute_error: 1.1991 - mean_squared_error: 2.1995
# Epoch 56/100
# 75000/75000 [==============================] - 9s 118us/sample - loss: 2.1873 - mean_absolute_error: 1.1944 - mean_squared_error: 2.1873
# Epoch 57/100
# 75000/75000 [==============================] - 9s 123us/sample - loss: 2.1873 - mean_absolute_error: 1.1966 - mean_squared_error: 2.1873
# Epoch 58/100
# 75000/75000 [==============================] - 9s 119us/sample - loss: 2.1587 - mean_absolute_error: 1.1878 - mean_squared_error: 2.1587
# Epoch 59/100
# 75000/75000 [==============================] - 9s 119us/sample - loss: 2.1432 - mean_absolute_error: 1.1835 - mean_squared_error: 2.1432
# Epoch 60/100
# 75000/75000 [==============================] - 9s 116us/sample - loss: 2.1386 - mean_absolute_error: 1.1816 - mean_squared_error: 2.1386
# Epoch 61/100
# 75000/75000 [==============================] - 9s 116us/sample - loss: 2.1269 - mean_absolute_error: 1.1788 - mean_squared_error: 2.1269
# Epoch 62/100
# 75000/75000 [==============================] - 9s 121us/sample - loss: 2.1126 - mean_absolute_error: 1.1763 - mean_squared_error: 2.1126
# Epoch 63/100
# 75000/75000 [==============================] - 9s 121us/sample - loss: 2.1046 - mean_absolute_error: 1.1737 - mean_squared_error: 2.1046
# Epoch 64/100
# 75000/75000 [==============================] - 9s 120us/sample - loss: 2.1060 - mean_absolute_error: 1.1758 - mean_squared_error: 2.1060
# Epoch 65/100
# 75000/75000 [==============================] - 9s 125us/sample - loss: 2.0853 - mean_absolute_error: 1.1687 - mean_squared_error: 2.0853
# Epoch 66/100
# 75000/75000 [==============================] - 9s 120us/sample - loss: 2.1034 - mean_absolute_error: 1.1739 - mean_squared_error: 2.1034
# Epoch 67/100
# 75000/75000 [==============================] - 9s 123us/sample - loss: 2.0897 - mean_absolute_error: 1.1691 - mean_squared_error: 2.0897
# Epoch 68/100
# 75000/75000 [==============================] - 9s 122us/sample - loss: 2.1016 - mean_absolute_error: 1.1702 - mean_squared_error: 2.1016
# Epoch 69/100
# 75000/75000 [==============================] - 9s 119us/sample - loss: 2.0944 - mean_absolute_error: 1.1711 - mean_squared_error: 2.0944
# Epoch 70/100
# 75000/75000 [==============================] - 9s 120us/sample - loss: 2.0841 - mean_absolute_error: 1.1688 - mean_squared_error: 2.0841
# Epoch 71/100
# 75000/75000 [==============================] - 9s 123us/sample - loss: 2.0855 - mean_absolute_error: 1.1676 - mean_squared_error: 2.0855
# Epoch 72/100
# 75000/75000 [==============================] - 9s 124us/sample - loss: 2.0816 - mean_absolute_error: 1.1671 - mean_squared_error: 2.0816
# Epoch 73/100
# 75000/75000 [==============================] - 9s 124us/sample - loss: 2.0746 - mean_absolute_error: 1.1644 - mean_squared_error: 2.0746
# Epoch 74/100
# 75000/75000 [==============================] - 9s 125us/sample - loss: 2.0563 - mean_absolute_error: 1.1598 - mean_squared_error: 2.0563
# Epoch 75/100
# 75000/75000 [==============================] - 9s 126us/sample - loss: 2.0532 - mean_absolute_error: 1.1603 - mean_squared_error: 2.0532
# Epoch 76/100
# 75000/75000 [==============================] - 9s 123us/sample - loss: 2.0610 - mean_absolute_error: 1.1632 - mean_squared_error: 2.0610
# Epoch 77/100
# 75000/75000 [==============================] - 9s 121us/sample - loss: 2.0514 - mean_absolute_error: 1.1604 - mean_squared_error: 2.0514
# Epoch 78/100
# 75000/75000 [==============================] - 9s 122us/sample - loss: 2.0307 - mean_absolute_error: 1.1518 - mean_squared_error: 2.0307
# Epoch 79/100
# 75000/75000 [==============================] - 9s 121us/sample - loss: 2.0215 - mean_absolute_error: 1.1516 - mean_squared_error: 2.0215
# Epoch 80/100
# 75000/75000 [==============================] - 9s 120us/sample - loss: 2.0170 - mean_absolute_error: 1.1487 - mean_squared_error: 2.0170
# Epoch 81/100
# 75000/75000 [==============================] - 9s 114us/sample - loss: 2.0264 - mean_absolute_error: 1.1544 - mean_squared_error: 2.0264
# Epoch 82/100
# 75000/75000 [==============================] - 9s 120us/sample - loss: 2.0209 - mean_absolute_error: 1.1502 - mean_squared_error: 2.0209
# Epoch 83/100
# 75000/75000 [==============================] - 9s 123us/sample - loss: 2.0267 - mean_absolute_error: 1.1526 - mean_squared_error: 2.0267
# Epoch 84/100
# 75000/75000 [==============================] - 9s 121us/sample - loss: 2.0229 - mean_absolute_error: 1.1517 - mean_squared_error: 2.0229
# Epoch 85/100
# 75000/75000 [==============================] - 9s 123us/sample - loss: 2.0142 - mean_absolute_error: 1.1490 - mean_squared_error: 2.0142
# Epoch 86/100
# 75000/75000 [==============================] - 9s 126us/sample - loss: 2.0090 - mean_absolute_error: 1.1483 - mean_squared_error: 2.0090
# Epoch 87/100
# 75000/75000 [==============================] - 9s 119us/sample - loss: 2.0099 - mean_absolute_error: 1.1483 - mean_squared_error: 2.0099
# Epoch 88/100
# 75000/75000 [==============================] - 9s 121us/sample - loss: 2.0094 - mean_absolute_error: 1.1476 - mean_squared_error: 2.0094
# Epoch 89/100
# 75000/75000 [==============================] - 9s 120us/sample - loss: 2.0123 - mean_absolute_error: 1.1478 - mean_squared_error: 2.0123
# Epoch 90/100
# 75000/75000 [==============================] - 9s 119us/sample - loss: 2.0043 - mean_absolute_error: 1.1461 - mean_squared_error: 2.0043
# Epoch 91/100
# 75000/75000 [==============================] - 9s 117us/sample - loss: 1.9988 - mean_absolute_error: 1.1436 - mean_squared_error: 1.9988
# Epoch 92/100
# 75000/75000 [==============================] - 9s 123us/sample - loss: 2.0102 - mean_absolute_error: 1.1487 - mean_squared_error: 2.0102
# Epoch 93/100
# 75000/75000 [==============================] - 9s 121us/sample - loss: 2.0125 - mean_absolute_error: 1.1490 - mean_squared_error: 2.0125
# Epoch 94/100
# 75000/75000 [==============================] - 9s 122us/sample - loss: 1.9923 - mean_absolute_error: 1.1423 - mean_squared_error: 1.9923
# Epoch 95/100
# 75000/75000 [==============================] - 9s 124us/sample - loss: 1.9976 - mean_absolute_error: 1.1445 - mean_squared_error: 1.9976
# Epoch 96/100
# 75000/75000 [==============================] - 9s 123us/sample - loss: 1.9964 - mean_absolute_error: 1.1435 - mean_squared_error: 1.9964
# Epoch 97/100
# 75000/75000 [==============================] - 9s 120us/sample - loss: 1.9935 - mean_absolute_error: 1.1423 - mean_squared_error: 1.9935
# Epoch 98/100
# 75000/75000 [==============================] - 9s 125us/sample - loss: 2.0087 - mean_absolute_error: 1.1477 - mean_squared_error: 2.0087
# Epoch 99/100
# 75000/75000 [==============================] - 9s 125us/sample - loss: 1.9961 - mean_absolute_error: 1.1453 - mean_squared_error: 1.9961
# Epoch 100/100
# 75000/75000 [==============================] - 9s 120us/sample - loss: 1.9823 - mean_absolute_error: 1.1411 - mean_squared_error: 1.9823

# %%
model.evaluate(X_test, y_test)
# Out:
# 25000/25000 [==============================] - 2s 64us/sample - loss: 1.5049 - mean_absolute_error: 1.0058 - mean_squared_error: 1.5049
# [1.5049378686141968, 1.0057887, 1.5049382]

# %%
y_hat = model.predict(X_test)

# %%
# some predictions will be > 5. We round y_hat down to 5 if y_hat > 5.
y_hat[y_hat > 5.] = 5
# Out:
# array([4.973141 , 4.8510685, 4.881345 , 5.       , 4.866328 , 4.8612633,
#        4.91703  , 4.8830423, 5.       , 4.802253 , 4.867864 , 5.       ,
#        5.       , 5.       , 4.8253403, 5.       , 5.       , 5.       ,
#        4.8666697, 5.       , 5.       , 5.       , 4.924727 , 5.       ,
#        5.       , 5.       , 4.930423 , 4.8336596, 5.       , 4.8932214,
#        4.895593 , 5.       , 5.       , 4.847019 , 5.       , 4.813768 ,
#        4.8088655, 5.       , 5.       , 4.872428 , 4.836344 , 5.       ,
#        4.8302813, 5.       , 4.8366776, 5.       , 4.8516464, 4.841177 ,
#        5.       , 5.       , 4.8973064, 4.8512096, 4.900649 , 5.       ,
#        4.802587 , 4.8379874, 4.88648  , 5.       , 4.9676666, 4.891804 ,
#        5.       ], dtype=float32)

# %%
# !pip install plotly==4.4.1
# Out:
# Collecting plotly==4.4.1
#   Downloading https://files.pythonhosted.org/packages/8e/ce/6ea5683c47b682bffad39ad41d10913141b560b1b875a90dbc6abe3f4fa9/plotly-4.4.1-py2.py3-none-any.whl (7.3MB)
#      |████████████████████████████████| 7.3MB 3.2MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from plotly==4.4.1) (1.12.0)
# Requirement already satisfied: retrying>=1.3.3 in /usr/local/lib/python3.6/dist-packages (from plotly==4.4.1) (1.3.3)
# Installing collected packages: plotly
#   Found existing installation: plotly 4.1.1
#     Uninstalling plotly-4.1.1:
#       Successfully uninstalled plotly-4.1.1
# Successfully installed plotly-4.4.1

# %%
pca = PCA(n_components=2)
pca_fit = pca.fit_transform(X_test)
pc1 = pca_fit[:, 0]
pc2 = pca_fit[:, 1]

# %%
kmeans = KMeans(n_clusters=64)
kmeans_fit = kmeans.fit_predict(pc1.reshape(-1, 1), pc2.reshape(-1, 1))
kmeans_fit
# Out:
# array([19, 53,  1, ..., 15,  4, 40], dtype=int32)

# %%
import plotly.express as px
fig = px.scatter_3d(x=pc1, y=pc2, z=y_hat, color=kmeans_fit)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="a99f8728-b240-4905-9387-273af3845eda" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a99f8728-b240-4905-9387-273af3845eda")) {
#                     Plotly.newPlot(
#                         'a99f8728-b240-4905-9387-273af3845eda',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "x=%{x}<br>y=%{y}<br>z=%{z}<br>color=%{marker.color}", "legendgroup": "", "marker": {"color":