# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
# logistic random variable x
x = np.random.logistic(loc=0, scale=1, size=1000)

# %%
px = 1/(1+np.exp(-x))

# %%
plt.scatter(x, px)
plt.show()
